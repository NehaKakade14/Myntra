# %%
import pandas as pd
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split, cross_validate
from surprise import accuracy
from surprise.prediction_algorithms.knns import KNNBasic

# %%
# Load the dataset
df = pd.read_csv('DummyMyntraDataset2.csv')  # Replace with your dataset file path

# Assume all interactions are from a single user with user_id = 1
df['user_id'] = 1

# Create a 'swipe' column based on 'No of Right Swipes'
df['swipe'] = df['No of Right Swipes'].apply(lambda x: 1 if x > 0 else 0)  # 1 for right swipe, 0 for no right swipe

# Prepare data for collaborative filtering
reader = Reader(rating_scale=(0, 1))  # Assuming 0 for left swipe, 1 for right swipe
data = Dataset.load_from_df(df[['user_id', 'p_id', 'swipe']], reader)

# Split the data into training and testing sets
trainset, testset = train_test_split(data, test_size=0.25)

# Use Singular Value Decomposition (SVD) for collaborative filtering
algo = SVD()
algo.fit(trainset)

# Test the algorithm on the testset
predictions = algo.test(testset)
print("RMSE:", accuracy.rmse(predictions))
# Out:
# RMSE: 0.0000
# RMSE: 0.0

# %%
import pandas as pd
from surprise import Dataset, Reader, SVD, KNNBasic
from surprise.model_selection import train_test_split, cross_validate
from surprise import accuracy
from surprise.prediction_algorithms.knns import KNNBasic
from sklearn.metrics import precision_score, recall_score

# Assume all interactions are from a single user with user_id = 1
df['user_id'] = 1

# Create a 'swipe' column based on 'No of Right Swipes'
df['swipe'] = df['No of Right Swipes'].apply(lambda x: 1 if x > 0 else 0)  # 1 for right swipe, 0 for no right swipe

# Prepare data for collaborative filtering
reader = Reader(rating_scale=(0, 1))  # Assuming 0 for left swipe, 1 for right swipe
data = Dataset.load_from_df(df[['user_id', 'p_id', 'swipe']], reader)

# Split the data into training and testing sets
trainset, testset = train_test_split(data, test_size=0.25)

# Use Singular Value Decomposition (SVD) for collaborative filtering
algo = SVD()
algo.fit(trainset)

# Test the algorithm on the testset
predictions = algo.test(testset)

# Compute RMSE
rmse = accuracy.rmse(predictions)
print("RMSE:", rmse)

# Compute Precision and Recall using test set predictions
y_true = [pred.r_ui for pred in predictions]  # Actual swipe values
y_pred = [round(pred.est) for pred in predictions]  # Predicted swipe values

precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)

print(f"Precision: {precision}")
print(f"Recall: {recall}")

# Example of using KNNBasic for comparison
# Use KNNBasic for collaborative filtering
knn_algo = KNNBasic()
knn_algo.fit(trainset)

# Get predictions for the test set
knn_predictions = knn_algo.test(testset)

# Compute RMSE for KNNBasic
knn_rmse = accuracy.rmse(knn_predictions)
print("\nKNNBasic RMSE:", knn_rmse)

# Compute Precision and Recall for KNNBasic
knn_y_pred = [round(pred.est) for pred in knn_predictions]

knn_precision = precision_score(y_true, knn_y_pred)
knn_recall = recall_score(y_true, knn_y_pred)

print(f"KNNBasic Precision: {knn_precision}")
print(f"KNNBasic Recall: {knn_recall}")
# Out:
# RMSE: 0.0000
# RMSE: 0.0
# Precision: 1.0
# Recall: 1.0
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0141
#
# KNNBasic RMSE: 0.014084507042253502
# KNNBasic Precision: 1.0
# KNNBasic Recall: 1.0

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

# %%
import pandas as pd
import requests

# Assuming 'img' column contains URLs to images
for index, row in df.iterrows():
    img_url = row['img']
    try:
        response = requests.get(img_url)
        if response.status_code == 200:
            print(f"Image URL {img_url} is accessible.")
        else:
            print(f"Image URL {img_url} returned status code {response.status_code}.")
    except Exception as e:
        print(f"Error accessing image URL {img_url}: {str(e)}")
# Out:
# Image URL http://assets.myntassets.com/assets/images/17048614/2022/2/4/b0eb9426-adf2-4802-a6b3-5dbacbc5f2511643971561167KhushalKWomenBlackEthnicMotifsAngrakhaBeadsandStonesKurtawit7.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/16524740/2021/12/29/17ab2ac8-2e60-422d-9d20-2527415932361640754214931-STRAPPY-SET-IN-ORANGE-WITH-ORGANZA-DUPATTA-5961640754214349-2.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/16331376/2021/12/2/b8c4f90f-683c-48d2-b8ac-19891a87c0651638428628378KurtaSets1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14709966/2021/7/10/d2407657-1f04-4d13-9f52-9e134050489b1625905793495-Nayo-Women-Red-Ethnic-Motifs-Printed-Empire-Pure-Cotton-Kurt-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/11056154/2019/12/5/30b0017d-7e72-4d40-9633-ef78d01719741575541717470-AHIKA-Women-Black--Green-Printed-Straight-Kurta-990157554171-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18704418/2022/6/11/507490f7-c8f9-492c-b3f8-c7e977d1af701654922515416SochWomenRedThreadWorkGeorgetteAnarkaliKurta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14046594/2022/6/9/5fba9594-3301-4881-ba56-d56a44570e831654747998773LibasWomenNavyBluePureCottonFloralPrintKurtawithPalazzosDupa1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14951330/2022/2/16/e6b90907-a613-45e1-9b2e-988caaba36581645010770505-Ahalyaa-Women-Beige-Floral-Printed-Regular-Gotta-Patti-Kurta-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/13791594/2022/2/14/5ea707f4-8491-4d1c-b520-86a1cff4c86e1644841891629-Anouk-Women-Yellow--White-Printed-Kurta-with-Palazzos-706164-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17048604/2022/2/4/11b842c5-d9d4-4fee-baa2-0972e3a673641643970773675KhushalKWomenGreenEthnicMotifsPrintedEmpireGottaPattiPureCot7.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/10356859/2019/8/8/b783aef9-c902-462e-af73-de159bfd011c1565256752191-Libas-Women-Kurta-Sets-2081565256750830-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/12413214/2021/11/22/bb925efb-80d9-4cb6-838c-df86f1ba3c3e1637570416652-Varanga-Women-Mustard-Yellow-Floral-Yoke-Embroidered-Straigh-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/16600750/2021/12/23/7d7656e5-e37d-4f61-9407-98bd341ca8f91640261029836KurtaSets1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/9867983/2019/5/31/43d65352-9853-498e-95a4-be514df0be901559294212152-Vishudh--Straight-Kurta-With-Crop-Palazzo-7041559294209627-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14399798/2022/4/20/4a37718e-8942-479c-a7ea-0b074d53ee4b1650456566424AnoukWomenPeach-ColouredYokeDesignMirror-WorkKurtawithTrouse1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18372852/2022/7/20/5910af54-3435-40d5-95d4-0ac2daf797f51658319613886-SheWill-Women-Maroon-Ethnic-Yoke-Design-Embroided-Kurta-with-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15241816/2021/8/24/d57adb8b-e792-477a-8801-6ea570cd88ef1629800170287VarangaWomenYellowFloralPrintedKeyholeNeckThreadWorkKurta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15055304/2021/8/27/0d391a8b-ea8c-4258-86d5-a99b9f3f34201630040200642-Libas-Women-Kurta-Sets-5941630040199555-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/productimage/2021/6/25/d6b74d2b-825f-4b34-af01-9d6336045bdb1624612149604-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17581924/2022/3/19/07adcdf7-eee1-4077-b55c-f6608caaa6f01647663614971KALINIWomenSeaGreenFloralYokeDesignPleatedPureCottonTopwithS4.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/13810898/2021/4/6/6bc412bb-3cc6-4def-8833-f5580b0cc06a1617706648250-Indo-Era-Green-Printed-Straight-Kurta-Palazzo-With-Dupatta-S-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15150620/2021/9/8/b1bd0687-7533-428d-8258-d29c793fc4541631092430795-Anouk-Women-Kurta-Sets-941631092429795-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/19240246/2022/7/25/64e975d5-dbda-4c09-87c0-c5152f9e82c71658736715566TOULINWomenTealFloralAngrakhaKurtiwithPalazzosWithDupatta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/12766966/2020/11/19/d1a4cc48-ff90-47ab-ad36-800743e83d641605767381033-Ishin-Womens-Rayon-Red-Bandhani-Print-Embellished-Anarkali-K-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/productimage/2021/4/5/195aae75-105f-44f3-95d8-04c04501de851617598475258-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/productimage/2021/5/19/3d4648ec-8534-4333-ba00-71f016a7889c1621410078449-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18829920/2022/6/23/4df23875-c0d5-4e8d-bf0e-b1a6e39fd6581655970565935VirahFashionWomenLimeGreenEmbroideredLayeredThreadWorkTopwit1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/11459658/2020/2/15/9b7f8d3f-e48f-4618-8eac-32cee1a0d4111581757541745-Indo-Era-Maroon-Floral-Printed-A-Line-Kurta-with-Palazzo-Set-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/16522612/2021/12/27/ee378dc7-1065-4ae0-8cb6-4afb40cc27581640597727510-KVS-Fab-Pink-Rayon-Foli-Print--Stitched-Embroidery--Kurta-Se-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15150642/2021/9/9/68ccde4c-f0fe-487d-9fa2-0aa4231a7dcf1631170046519-Anouk-Women-Kurta-Sets-801631170045543-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/12246214/2021/1/21/fb8fc504-76cd-4d6a-a16e-e20bdc7bebe41611204555225-Ahalyaa-Women-Maroon--Gold-Printed-Kurti-with-Sharara--Dupat-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/9438657/2019/5/8/5f44fbff-658c-40f2-ae17-4ae52b7381e31557297223910-AASI---HOUSE-OF-NAYO-Women-Black--Mustard-Solid-Kurta-with-T-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/16331336/2021/12/2/8fa4f922-c4fc-4c4d-8aad-8c28ece5ff2e1638428914896KurtaSets1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/7763575/2021/1/27/ed5edf7d-db8e-4c05-bac6-3bd4979418a21611738222844-Anouk-Women-Red-Floral-Print-A-Line-Kurta-6991611738221560-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/19357994/2022/8/3/c9d70fb4-dfd1-41e4-9538-fd3a30c19b5c1659500359962FASHORWomenPinkEthnicMotifsThreadWorkKurta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18957838/2022/7/4/58ff6c28-b599-4a63-9627-d9cc7a35966c1656932528424KALINIWomenFluorescentGreenEthnicMotifsEmbroideredPleatedPur1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18425500/2022/5/26/548b3242-c4b0-4a01-a7c8-dbd25721ed101653557566916BlockPrintedPinkKurta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14925332/2021/9/2/9fdeb696-bce1-4791-aa1a-3dbfe5e9a5c51630583727539HERENOWMenPinkWhiteTypographyPrintedOrganicCottonT-shirtKurt1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18811288/2022/7/5/edbf3557-d768-49fd-8c80-c56427f2e81c1657018117840-SheWill-Blue-Muslin-Sequence-Zari-Embroidered-Straight-Kurta-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15646472/2021/9/28/a5a4e093-dfd6-4a1b-8c1f-c7b46f27678d1632833511024VarangaWomenRedEthnicMotifsPrintedGottaPattiKurta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18503778/2022/5/30/6bd65bc0-6a32-4c55-9480-0f6e4c0382231653924747273KALINIAssamicaWomenPinkDyedKurtaPrintedShararawithDupatta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15561680/2021/9/22/ae87dd98-3d80-449b-bf62-3834797d9a561632315919781DIVYANKWomenNavyBlueEthnicMotifsPrintedRegularMirrorWorkKurt1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/16857670/2022/1/31/393262fb-2be4-4945-b3e8-a64336da74f01643629068794-Libas-Women-Kurta-Sets-3571643629067890-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/13437328/2021/2/26/1db98d09-8e2a-49b6-9521-d59d0764aa621614341754175-Sangria-Women-Kurta-Sets-9031614341752071-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/19181470/2022/7/20/fb88fbe3-b55c-4bbb-9f51-63d48ffe93fd1658298777250KurtaSets1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/12105006/2020/9/4/bce63f51-fa78-4456-a4ce-85d193628e761599199586248-Sangria-Women-Pink--Gold-Toned-Printed-Kurta-with-Trousers-8-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17487194/2022/3/21/2dd80782-75be-496b-8bac-2978541418161647846846121-Libas-Women-Kurta-Sets-7321647846845273-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/11636314/2022/4/18/c4ffb5ae-4483-4e2c-ba02-c38e2adb11361650283630240ShaebySASSAFRASWomenBlueOff-WhitePrintedAnarkaliKurta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/16706794/2022/2/16/59d4aa7a-f05c-4eda-b796-a45078f798371645012473502-Varanga-Magenta-Net-Strap-Straight-Kurta-With-Flared-Sharara-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17140538/2022/2/12/26bea60e-1753-4bf1-8a9e-96f060de329d1644644643001MyshkaWomenPinkEthnicMotifsEmbroideredLayeredPureCottonKurti1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14224616/2021/8/19/64e6b083-6b6f-4c71-bf89-4a4483d401e01629350582004-Anouk-Women-Kurtas-6181629350581610-6.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/19145056/2022/7/18/3e8fbc23-d331-453a-9716-01945b5eab0d1658132992086BaisacraftsWomenRedEmbroideredPleatedPureCottonKurtawithChur1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15508918/2021/10/6/b1732025-43d1-4413-9843-090cd40a6f591633518810684-Indo-Era-Women-Yellow-Floral-Yoke-Design-Regular-Kurta-with--1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17197472/2022/2/18/5934fceb-05cf-40c2-87e8-3fe9fd474c1e1645166780554heemaraWomenPurpleFloralEmbroideredThreadWorkSilkChiffonKurt1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/13238316/2021/2/22/71fe0645-db94-4b06-a96c-292eb7da7d5c1613990092576-Anouk-Purple-Striped-Kurta-2011613990090496-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/3077373/2022/4/18/f0048a52-17b7-4a0b-8925-5cfad761ca201650284995022HERENOWWomenWhiteSolidStraightKurta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18859760/2022/6/24/716a819b-f77b-482e-a13f-4f64458029051656076922438KurtaSets1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/16919764/2022/8/4/339f3e1e-8e1b-492f-b5b3-78349fa4bcf01659630518697RustorangeWomenMustardYellowFloralPrintedAngrakhaKurtiwithSh1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/16941854/2022/1/27/b0665d71-1b34-4089-8e95-4cebf640a6631643256625686VarangaWomenLavenderEmbroideredPanelledGottaPattiPureCottonK1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15889764/2022/2/14/4da81903-deda-42c5-9e3e-1607fa11524f1644842837193-HERENOW-Women-Green--White-Pure-Cotton-Ethnic-Motifs-Printed-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/8529019/2019/1/23/5d6a8e02-0fa0-4770-82f5-6b52d9c983561548242338312-Varanga-mustard-printed-straight-kurta-6361548242336928-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17132180/2022/2/12/bc780386-c2d5-475a-ba45-14d965957c5c1644641530795VishudhWomenBlackPleatedPureCottonKurtiwithTrousersWithDupat1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14967448/2021/9/24/797117a8-153b-4dc0-a33e-5d2e82ef80701632484239222-Indo-Era-Women-Green-Ethnic-Motifs-Printed-Panelled-Gotta-Pa-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14224394/2022/6/26/f02f2ce3-11db-47df-a6a8-4bc9041ce3c21656219851811NayoWomenMustardPrintedStraightKurtaWithPlazzoDupatta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/7156696/2018/8/16/6aba666c-f72f-4ba5-a619-c30997225dce1534400511956-na-8931534400511655-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17193226/2022/2/17/7738c355-5ff9-4962-b833-23298e5a34e11645094189571KALINIWomenTurquoiseBlueGottaPattiKurtiwithShararaWithDupatt1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14949672/2021/7/27/b1fbf2ec-09d2-46bb-89f8-91849ebac9a61627375681803StylumWomenPinkEthnicMotifsPrintedPureCottonKurtawithPalazzo1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/9370965/2019/5/14/9982bdc8-079f-4c91-b1a2-1b055a5179ad1557838905565-Sangria-Women-Kurtas-7181557838904365-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/11434632/2020/3/3/8b311761-20c2-44b1-94a9-0d1bc522fd9a1583235378025-Inddus-Women-Red-Embroidered-Kurta-with-Trousers--Dupatta-30-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/13962368/2021/7/6/7aac3b5c-bf62-48a1-9398-67a0e15576c41625560897635-Indo-Era-Off-White-Floral-Printed-Straight-Kurta-Palazzo-Wit-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/13932904/2021/4/14/e0c3f8f6-6f8f-4c68-b59f-5f39085542e01618405482652AnaynaWomensStraightKurta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18198270/2022/7/12/575c27b1-24d8-4363-b5a3-845a29d58c701657628613129-Biba-Women-Kurtas-9431657628612606-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17104862/2022/5/30/aba2d12a-9488-49f7-846c-cd14ae01c1aa1653895702692-Anouk-Women-Kurta-Sets-7141653895701947-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/19240240/2022/7/25/3c108049-c90e-464b-87c8-10c6b0ea95ad1658728557057CharuWomenMaroonFlaredSleevesThreadWorkKurta1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15150344/2021/8/27/dd03fc19-04db-4b1d-a548-2bbb7dcf560f1630048191438JuniperMintRayonCrepeSelfDesignStraightTopKurtaSetsYuftaWome7.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18165350/2022/6/1/75b8bd49-918a-4e97-a46b-b65384f064761654078529049-Indo-Era-Pink-Floral-Embroidered-Straight-Kurta-Trouser-With-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/productimage/2020/8/20/ef06dc09-c1f6-43a5-8c54-a0e85a47c10b1597876200592-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/19261926/2022/7/26/0a16e357-7d8a-4bf3-9606-b8228896f9a01658839382866KurtaSets1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15390174/2021/9/27/5ed13e8f-0618-4813-ac99-f70ecab4ea441632739003147IndoEraBlueKhariPrintedStraightKurtaPalazzoWithDupattaSets1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17447636/2022/3/9/de7c003c-2f74-4c6f-b7d0-c7c1566ad7981646801368575KhushalKWomenGreenEthnicMotifsPrintedPanelledGottaPattiKurta7.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17487138/2022/5/13/400c86e5-2205-459f-af9c-1e61da3a84861652423040056-Libas-Women-Green--Gold-Toned-Geometric-Print-Gotta-Patti-Ku-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/16707970/2022/1/24/dd9d566a-e774-4621-b4e6-7a2ade3572dc1643024012122-mokshi-Women-Kurta-Sets-2901643024011607-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14121926/2021/9/16/ea2825f1-ab9c-4376-9075-d1fc29cbb55f1631771913472-Anouk-Women-Kurta-Sets-6211631771912593-11.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17952212/2022/5/24/e3b256cb-96c6-4a5b-9a3a-ad67a1cceb161653367344592-Biba-Women-Kurta-Sets-6921653367343867-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/13572242/2021/2/24/c5300d99-77f9-4daa-a27c-85ebe46854881614167698599AnubhuteeWomenGreenBluePrintedKurtawithTrousers1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15921898/2021/11/25/e37b678e-01b1-43a6-93d7-55ed2d34aea81637824706825KurtaSetsDivenaWomenKurtaSetsDivenaWomenKurtaSetsDivenaWomen1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/19222130/2022/7/22/2d853c41-1f14-411d-a5e1-39b7b899dece1658485405643KurtaSets1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/19048738/2022/7/11/35e529f9-b351-4c35-a49c-2ece2a7b9ec51657529078380KurtaSets1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17320642/2022/2/28/9df28461-0fb1-4f06-b0aa-7c8b1d9fc4f01646033586343NayoWomenNavyBlueFloralEmbroideredPanelledPureCottonKurtiwit1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/10317841/2019/8/8/dc7bb0aa-34f6-435a-9649-f7381927ba251565268692798-Jaipur-Kurti-Women-Kurta-Sets-6041565268691298-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/18929148/2022/7/1/7a6c7397-7bc3-4f19-8ab8-ba126444b0611656672761489VishudhWomenTurquoiseBluePleatedKurtiwithDhotiPantsWithDupat1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/14848486/2021/9/1/849c44d7-0274-49fa-bb15-c5d786b74e351630497951879-Biba-Women-Yellow-Printed-Regular-Gotta-Patti-Kurta-with-Tro-1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/19265068/2022/7/27/aa4d0af3-23d2-4a01-b029-6783f01ac6531658894918812BaisacraftsWomenMagentaEthnicMotifsPrintedPureCottonKurtawit1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/15798294/2021/10/12/900caf30-08c1-43a9-a2c4-09534e608a6c1634021324400IndoEraWomenPinkEmbroideredPanelledKurtiwithTrousersWithDupa1.jpg is accessible.
# Image URL http://assets.myntassets.com/assets/images/17193238/2022/2/17/1cfda136-56ea-48e0-97b6-77a4c22a2c541645095163249KALINIWomenGreenFloralPrintedGottaPattiKurtawithSharara1.jpg is accessible.

# %%
# Combine relevant columns into a single string for each product
columns_to_combine = ['name', 'colour', 'brand', 'Body Shape ID', 'Body or Garment Size', 'Bottom Closure',
                      'Bottom Fabric', 'Bottom Pattern', 'Bottom Type', 'Dupatta', 'Dupatta Border', 
                      'Dupatta Fabric', 'Dupatta Pattern', 'Main Trend', 'Neck', 'Number of Pockets', 
                      'Occasion', 'Pattern Coverage', 'Print or Pattern Type', 'Sleeve Length', 
                      'Sleeve Styling', 'Slit Detail', 'Stitch', 'Sustainable', 'Top Design Styling', 
                      'Top Fabric', 'Top Hemline', 'Top Length', 'Top Pattern', 'Top Shape', 'Top Type', 
                      'Waistband', 'Wash Care', 'Weave Pattern', 'Weave Type', 'Ornamentation']

# Fill NaN values with empty string
df[columns_to_combine] = df[columns_to_combine].fillna('')

# Combine the columns into a single 'description' column
df['description'] = df[columns_to_combine].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# Normalize the numeric columns
numeric_columns = ['No of Right Swipes', 'No of rents', 'ratingCount', 'avg_rating']
scaler = MinMaxScaler()
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# Create a TF-IDF Vectorizer to transform product descriptions into vectors
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['description'])

# Combine TF-IDF vectors with normalized numeric features
tfidf_df = pd.DataFrame(tfidf_matrix.toarray())
combined_features = pd.concat([tfidf_df, df[numeric_columns].reset_index(drop=True)], axis=1)

# Compute the cosine similarity matrix
cosine_sim = cosine_similarity(combined_features)

# Function to get recommendations based on product index
def get_recommendations(product_index, cosine_sim=cosine_sim):
    sim_scores = list(enumerate(cosine_sim[product_index]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # Get top 10 similar products
    product_indices = [i[0] for i in sim_scores]
    return df.iloc[product_indices]

# Example usage
product_index = 45  # Replace with a valid product index
recommended_products = get_recommendations(product_index)
print(recommended_products[['p_id', 'img' ,'name', 'No of Right Swipes', 'No of rents', 'ratingCount', 'avg_rating']])
# Out:
#         p_id                                                img  \
# 66  14949672  http://assets.myntassets.com/assets/images/149...
# 25  14346084  http://assets.myntassets.com/assets/images/pro...
# 62  14967448  http://assets.myntassets.com/assets/images/149...
# 43  13437328  http://assets.myntassets.com/assets/images/134...
# 84  13572242  http://assets.myntassets.com/assets/images/135...
# 44  19181470  http://assets.myntassets.com/assets/images/191...
# 9   17048604  http://assets.myntassets.com/assets/images/170...
# 85  15921898  http://assets.myntassets.com/assets/images/159...
# 77  19261926  http://assets.myntassets.com/assets/images/192...
# 20  13810898  http://assets.myntassets.com/assets/images/138...
#
#                                                  name  No of Right Swipes  \
# 66  Stylum Women Pink Ethnic Motifs Printed Pure C...            0.025888
# 25  Nayo Women Pink & Off-White Floral Screen Prin...            0.079674
# 62  Indo Era Women Green Ethnic Motifs Printed Pan...            0.014267
# 43  Sangria Women Beige & Black Pure Cotton Printe...            0.029170
# 84  Anubhutee Women Green & Blue Printed Kurta wit...            0.153053
# 44  Baisacrafts Women Green Striped Pure Cotton Ku...            0.029237
# 9   Khushal K Women Green & Pink Printed Pure Cott...            0.107740
# 85  Divena Women Pink Floral Embroidered Regular G...            0.007267
# 77  Baisacrafts Women's Blue Floral Dyed Pure Cott...            0.010985
# 20  Indo Era Women Blue & Green Printed Kurta with...            0.079507
#
#     No of rents  ratingCount  avg_rating
# 66     0.021678     0.018478    0.421762
# 25     0.077767     0.058395    0.756032
# 62     0.013007     0.009874    0.735838
# 43     0.027303     0.032630    0.543321
# 84     0.117061     0.127274    0.624804
# 44     0.027303     0.020687    0.488370
# 9      0.081986     0.074522    0.762659
# 85     0.004336     0.003103    0.952001
# 77     0.009101     0.003855    0.566801
# 20     0.077025     0.080493    0.786508

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity

# Combine relevant columns into a single string for each product
columns_to_combine = ['name', 'colour', 'brand', 'Body Shape ID', 'Body or Garment Size', 'Bottom Closure',
                      'Bottom Fabric', 'Bottom Pattern', 'Bottom Type', 'Dupatta', 'Dupatta Border', 
                      'Dupatta Fabric', 'Dupatta Pattern', 'Main Trend', 'Neck', 'Number of Pockets', 
                      'Occasion', 'Pattern Coverage', 'Print or Pattern Type', 'Sleeve Length', 
                      'Sleeve Styling', 'Slit Detail', 'Stitch', 'Sustainable', 'Top Design Styling', 
                      'Top Fabric', 'Top Hemline', 'Top Length', 'Top Pattern', 'Top Shape', 'Top Type', 
                      'Waistband', 'Wash Care', 'Weave Pattern', 'Weave Type', 'Ornamentation']

# Fill NaN values with empty string
df[columns_to_combine] = df[columns_to_combine].fillna('')

# Combine the columns into a single 'description' column
df['description'] = df[columns_to_combine].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# Normalize the numeric columns
numeric_columns = ['No of Right Swipes', 'No of rents', 'ratingCount', 'avg_rating']
scaler = MinMaxScaler()
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# Create a TF-IDF Vectorizer to transform product descriptions into vectors
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['description'])

# Combine TF-IDF vectors with normalized numeric features
tfidf_df = pd.DataFrame(tfidf_matrix.toarray())
combined_features = pd.concat([tfidf_df, df[numeric_columns].reset_index(drop=True)], axis=1)

# Compute the cosine similarity matrix
cosine_sim = cosine_similarity(combined_features)

# Function to get recommendations based on product index
def get_recommendations(product_index, cosine_sim=cosine_sim):
    sim_scores = list(enumerate(cosine_sim[product_index]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # Get top 10 similar products
    product_indices = [i[0] for i in sim_scores]
    return df.iloc[product_indices]

# Example usage
product_index = 45  # Replace with a valid product index
recommended_products = get_recommendations(product_index)

# Display recommended products with proper URLs
for index, row in recommended_products.iterrows():
    print(f"Product ID: {row['p_id']}")
    print(f"Name: {row['name']}")
    print(f"Image URL: {row['img']}")
    print(f"No of Right Swipes: {row['No of Right Swipes']}")
    print(f"No of rents: {row['No of rents']}")
    print(f"Rating Count: {row['ratingCount']}")
    print(f"Avg Rating: {row['avg_rating']}")
    print("\n")
# Out:
# Product ID: 14949672
# Name: Stylum Women Pink Ethnic Motifs Printed Pure Cotton Kurta with Trousers & Dupatta
# Image URL: http://assets.myntassets.com/assets/images/14949672/2021/7/27/b1fbf2ec-09d2-46bb-89f8-91849ebac9a61627375681803StylumWomenPinkEthnicMotifsPrintedPureCottonKurtawithPalazzo1.jpg
# No of Right Swipes: 0.02588834187347199
# No of rents: 0.021677993906726038
# Rating Count: 0.018477596501951195
# Avg Rating: 0.42176150851798155
#
#
# Product ID: 14346084
# Name: Nayo Women Pink & Off-White Floral Screen Print A-Line Pure Cotton Kurta Set With Dupatta
# Image URL: http://assets.myntassets.com/assets/images/productimage/2021/5/19/3d4648ec-8534-4333-ba00-71f016a7889c1621410078449-1.jpg
# No of Right Swipes: 0.07967447000904251
# No of rents: 0.07776736192484963
# Rating Count: 0.05839484696036485
# Avg Rating: 0.7560318964378929
#
#
# Product ID: 14967448
# Name: Indo Era Women Green Ethnic Motifs Printed Panelled Gotta Patti Pure Cotton Kurta with Trousers & With
# Image URL: http://assets.myntassets.com/assets/images/14967448/2021/9/24/797117a8-153b-4dc0-a33e-5d2e82ef80701632484239222-Indo-Era-Women-Green-Ethnic-Motifs-Printed-Panelled-Gotta-Pa-1.jpg
# No of Right Swipes: 0.014267055159248473
# No of rents: 0.013006796344035626
# Rating Count: 0.009873524848370868
# Avg Rating: 0.7358375427018782
#
#
# Product ID: 13437328
# Name: Sangria Women Beige & Black Pure Cotton Printed Kurta with Salwar
# Image URL: http://assets.myntassets.com/assets/images/13437328/2021/2/26/1db98d09-8e2a-49b6-9521-d59d0764aa621614341754175-Sangria-Women-Kurta-Sets-9031614341752071-1.jpg
# No of Right Swipes: 0.029170434374895346
# No of rents: 0.027302554487930633
# Rating Count: 0.032629648784616105
# Avg Rating: 0.5433214563056374
#
#
# Product ID: 13572242
# Name: Anubhutee Women Green & Blue Printed Kurta with Trousers
# Image URL: http://assets.myntassets.com/assets/images/13572242/2021/2/24/c5300d99-77f9-4daa-a27c-85ebe46854881614167698599AnubhuteeWomenGreenBluePrintedKurtawithTrousers1.jpg
# No of Right Swipes: 0.15305268093372185
# No of rents: 0.11706116709632063
# Rating Count: 0.1272744369739997
# Avg Rating: 0.6248044542309752
#
#
# Product ID: 19181470
# Name: Baisacrafts Women Green Striped Pure Cotton Kurta with Trousers & With Dupatta
# Image URL: http://assets.myntassets.com/assets/images/19181470/2022/7/20/fb88fbe3-b55c-4bbb-9f51-63d48ffe93fd1658298777250KurtaSets1.jpg
# No of Right Swipes: 0.02923741585451623
# No of rents: 0.027302554487930633
# Rating Count: 0.02068738539658658
# Avg Rating: 0.48837023141970715
#
#
# Product ID: 17048604
# Name: Khushal K Women Green & Pink Printed Pure Cotton Kurta with Palazzos & Dupatta
# Image URL: http://assets.myntassets.com/assets/images/17048604/2022/2/4/11b842c5-d9d4-4fee-baa2-0972e3a673641643970773675KhushalKWomenGreenEthnicMotifsPrintedEmpireGottaPattiPureCot7.jpg
# No of Right Swipes: 0.10773970997019328
# No of rents: 0.08198578236075307
# Rating Count: 0.07452160421270393
# Avg Rating: 0.7626593996398618
#
#
# Product ID: 15921898
# Name: Divena Women Pink Floral Embroidered Regular Gotta Patti Pure Cotton Kurta with Sharara & With Dupatta
# Image URL: http://assets.myntassets.com/assets/images/15921898/2021/11/25/e37b678e-01b1-43a6-93d7-55ed2d34aea81637824706825KurtaSetsDivenaWomenKurtaSetsDivenaWomenKurtaSetsDivenaWomen1.jpg
# No of Right Swipes: 0.0072674905388660045
# No of rents: 0.004335598781345208
# Rating Count: 0.003103107809487987
# Avg Rating: 0.9520008697846265
#
#
# Product ID: 19261926
# Name: Baisacrafts Women's Blue Floral Dyed Pure Cotton Kurti With Trousers & Dupatta
# Image URL: http://assets.myntassets.com/assets/images/19261926/2022/7/26/0a16e357-7d8a-4bf3-9606-b8228896f9a01658839382866KurtaSets1.jpg
# No of Right Swipes: 0.010984962657825113
# No of rents: 0.009100851495976878
# Rating Count: 0.0038553763693638626
# Avg Rating: 0.5668013229326023
#
#
# Product ID: 13810898
# Name: Indo Era Women Blue & Green Printed Kurta with Palazzos & Dupatta
# Image URL: http://assets.myntassets.com/assets/images/13810898/2021/4/6/6bc412bb-3cc6-4def-8833-f5580b0cc06a1617706648250-Indo-Era-Green-Printed-Straight-Kurta-Palazzo-With-Dupatta-S-1.jpg
# No of Right Swipes: 0.07950701630999031
# No of rents: 0.07702523240371847
# Rating Count: 0.0804927359067187
# Avg Rating: 0.7865080949812815

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity

# Sample dataset loading and preprocessing (replace with your actual dataset loading)
df = pd.read_csv('DummyMyntraDataset2.csv')  # Replace with your dataset file path

# Combine relevant columns into a single string for each product
columns_to_combine = ['name', 'colour', 'brand', 'Body Shape ID', 'Body or Garment Size', 'Bottom Closure',
                      'Bottom Fabric', 'Bottom Pattern', 'Bottom Type', 'Dupatta', 'Dupatta Border', 
                      'Dupatta Fabric', 'Dupatta Pattern', 'Main Trend', 'Neck', 'Number of Pockets', 
                      'Occasion', 'Pattern Coverage', 'Print or Pattern Type', 'Sleeve Length', 
                      'Sleeve Styling', 'Slit Detail', 'Stitch', 'Sustainable', 'Top Design Styling', 
                      'Top Fabric', 'Top Hemline', 'Top Length', 'Top Pattern', 'Top Shape', 'Top Type', 
                      'Waistband', 'Wash Care', 'Weave Pattern', 'Weave Type', 'Ornamentation']

# Fill NaN values with empty string
df[columns_to_combine] = df[columns_to_combine].fillna('')

# Combine the columns into a single 'description' column
df['description'] = df[columns_to_combine].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# Keep original numeric columns for display
original_numeric_columns = ['No of Right Swipes', 'No of rents', 'ratingCount', 'avg_rating']

# Normalize the numeric columns for similarity calculation
numeric_columns = ['No of Right Swipes', 'No of rents', 'ratingCount', 'avg_rating']
scaler = MinMaxScaler()
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# Create a TF-IDF Vectorizer to transform product descriptions into vectors
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['description'])

# Combine TF-IDF vectors with normalized numeric features
tfidf_df = pd.DataFrame(tfidf_matrix.toarray())
combined_features = pd.concat([tfidf_df, df[numeric_columns].reset_index(drop=True)], axis=1)

# Compute the cosine similarity matrix
cosine_sim = cosine_similarity(combined_features)

# Function to get recommendations based on product index
def get_recommendations(product_index, cosine_sim=cosine_sim):
    sim_scores = list(enumerate(cosine_sim[product_index]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # Get top 10 similar products
    product_indices = [i[0] for i in sim_scores]
    return df.iloc[product_indices]

# Example usage
product_index = 45  # Replace with a valid product index
recommended_products = get_recommendations(product_index)

# Display recommended products with proper URLs and original numeric values
for index, row in recommended_products.iterrows():
    print(f"Product ID: {row['p_id']}")
    print(f"Name: {row['name']}")
    print(f"Image URL: {row['img']}")
    print(f"No of Right Swipes: {int(row['No of Right Swipes'] * (scaler.data_max_[0] - scaler.data_min_[0]) + scaler.data_min_[0])}")
    print(f"No of rents: {int(row['No of rents'] * (scaler.data_max_[1] - scaler.data_min_[1]) + scaler.data_min_[1])}")
    print(f"Rating Count: {int(row['ratingCount'] * (scaler.data_max_[2] - scaler.data_min_[2]) + scaler.data_min_[2])}")
    print(f"Avg Rating: {row['avg_rating'] * (scaler.data_max_[3] - scaler.data_min_[3]) + scaler.data_min_[3]:.2f}")
    print("\n")
# Out:
# Product ID: 14949672
# Name: Stylum Women Pink Ethnic Motifs Printed Pure Cotton Kurta with Trousers & Dupatta
# Image URL: http://assets.myntassets.com/assets/images/14949672/2021/7/27/b1fbf2ec-09d2-46bb-89f8-91849ebac9a61627375681803StylumWomenPinkEthnicMotifsPrintedPureCottonKurtawithPalazzo1.jpg
# No of Right Swipes: 790
# No of rents: 566
# Rating Count: 397
# Avg Rating: 3.78
#
#
# Product ID: 14346084
# Name: Nayo Women Pink & Off-White Floral Screen Print A-Line Pure Cotton Kurta Set With Dupatta
# Image URL: http://assets.myntassets.com/assets/images/productimage/2021/5/19/3d4648ec-8534-4333-ba00-71f016a7889c1621410078449-1.jpg
# No of Right Swipes: 2396
# No of rents: 2003
# Rating Count: 1247
# Avg Rating: 4.26
#
#
# Product ID: 14967448
# Name: Indo Era Women Green Ethnic Motifs Printed Panelled Gotta Patti Pure Cotton Kurta with Trousers & With
# Image URL: http://assets.myntassets.com/assets/images/14967448/2021/9/24/797117a8-153b-4dc0-a33e-5d2e82ef80701632484239222-Indo-Era-Women-Green-Ethnic-Motifs-Printed-Panelled-Gotta-Pa-1.jpg
# No of Right Swipes: 443
# No of rents: 345
# Rating Count: 215
# Avg Rating: 4.23
#
#
# Product ID: 13437328
# Name: Sangria Women Beige & Black Pure Cotton Printed Kurta with Salwar
# Image URL: http://assets.myntassets.com/assets/images/13437328/2021/2/26/1db98d09-8e2a-49b6-9521-d59d0764aa621614341754175-Sangria-Women-Kurta-Sets-9031614341752071-1.jpg
# No of Right Swipes: 887
# No of rents: 710
# Rating Count: 699
# Avg Rating: 3.95
#
#
# Product ID: 13572242
# Name: Anubhutee Women Green & Blue Printed Kurta with Trousers
# Image URL: http://assets.myntassets.com/assets/images/13572242/2021/2/24/c5300d99-77f9-4daa-a27c-85ebe46854881614167698599AnubhuteeWomenGreenBluePrintedKurtawithTrousers1.jpg
# No of Right Swipes: 4587
# No of rents: 3009
# Rating Count: 2711
# Avg Rating: 4.07
#
#
# Product ID: 19181470
# Name: Baisacrafts Women Green Striped Pure Cotton Kurta with Trousers & With Dupatta
# Image URL: http://assets.myntassets.com/assets/images/19181470/2022/7/20/fb88fbe3-b55c-4bbb-9f51-63d48ffe93fd1658298777250KurtaSets1.jpg
# No of Right Swipes: 890
# No of rents: 710
# Rating Count: 444
# Avg Rating: 3.88
#
#
# Product ID: 17048604
# Name: Khushal K Women Green & Pink Printed Pure Cotton Kurta with Palazzos & Dupatta
# Image URL: http://assets.myntassets.com/assets/images/17048604/2022/2/4/11b842c5-d9d4-4fee-baa2-0972e3a673641643970773675KhushalKWomenGreenEthnicMotifsPrintedEmpireGottaPattiPureCot7.jpg
# No of Right Swipes: 3234
# No of rents: 2111
# Rating Count: 1589
# Avg Rating: 4.27
#
#
# Product ID: 15921898
# Name: Divena Women Pink Floral Embroidered Regular Gotta Patti Pure Cotton Kurta with Sharara & With Dupatta
# Image URL: http://assets.myntassets.com/assets/images/15921898/2021/11/25/e37b678e-01b1-43a6-93d7-55ed2d34aea81637824706825KurtaSetsDivenaWomenKurtaSetsDivenaWomenKurtaSetsDivenaWomen1.jpg
# No of Right Swipes: 233
# No of rents: 122
# Rating Count: 71
# Avg Rating: 4.54
#
#
# Product ID: 19261926
# Name: Baisacrafts Women's Blue Floral Dyed Pure Cotton Kurti With Trousers & Dupatta
# Image URL: http://assets.myntassets.com/assets/images/19261926/2022/7/26/0a16e357-7d8a-4bf3-9606-b8228896f9a01658839382866KurtaSets1.jpg
# No of Right Swipes: 345
# No of rents: 244
# Rating Count: 87
# Avg Rating: 3.99
#
#
# Product ID: 13810898
# Name: Indo Era Women Blue & Green Printed Kurta with Palazzos & Dupatta
# Image URL: http://assets.myntassets.com/assets/images/13810898/2021/4/6/6bc412bb-3cc6-4def-8833-f5580b0cc06a1617706648250-Indo-Era-Green-Printed-Straight-Kurta-Palazzo-With-Dupatta-S-1.jpg
# No of Right Swipes: 2391
# No of rents: 1984
# Rating Count: 1717
# Avg Rating: 4.30
